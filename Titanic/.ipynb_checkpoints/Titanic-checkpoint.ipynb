# %%
import csv as csv
import numpy as np
import pandas as pd
import matplotlib as P

# %matplotlib inline

csv_file_object = csv.reader(open('./train.csv', 'rb')) 
header = csv_file_object.next() 
data=[] 

for row in csv_file_object:
    data.append(row)
data = np.array(data)

# %%
type(data[0:15,5])
# Out:
# numpy.ndarray

# %%
# For .read_csv, always use header=0 when you know row 0 is the header row
df = pd.read_csv('train.csv', header=0)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[ ['Sex','Pclass','Age']][0:10]
# Out:
#       Sex  Pclass  Age
# 0    male       3   22
# 1  female       1   38
# 2  female       3   26
# 3  female       1   35
# 4    male       3   35
# 5    male       3  NaN
# 6    male       1   54
# 7    male       3    2
# 8  female       3   27
# 9  female       2   14

# %%
df[df['Age']>60][['Sex', 'Pclass', 'Age', 'Survived']]
# Out:
#         Sex  Pclass   Age  Survived
# 33     male       2  66.0         0
# 54     male       1  65.0         0
# 96     male       1  71.0         0
# 116    male       3  70.5         0
# 170    male       1  61.0         0
# 252    male       1  62.0         0
# 275  female       1  63.0         1
# 280    male       3  65.0         0
# 326    male       3  61.0         0
# 438    male       1  64.0         0
# 456    male       1  65.0         0
# 483  female       3  63.0         1
# 493    male       1  71.0         0
# 545    male       1  64.0         0
# 555    male       1  62.0         0
# 570    male       2  62.0         1
# 625    male       1  61.0         0
# 630    male       1  80.0         1
# 672    male       2  70.0         0
# 745    male       1  70.0         0
# 829  female       1  62.0         1
# 851    male       3  74.0         0

# %%
df[df['Age'].isnull()][['Sex', 'Pclass', 'Age', 'Survived']]

# %%
for i in range(1,4):
    print i, len(df[ (df['Pclass'] == i)  & (df['Sex'] == 'male') ] )
# Out:
# 1 122
# 2 108
# 3 347

# %%
df['Age'].hist()

# %%
df['Age'].dropna().hist(bins=16, range=(0,80), alpha = .5)

# %%
df['Gender']=df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
df['Start'] = df['Embarked'].map( {'C':0, 'S':1, 'Q':2})

# %%
median_ages = np.zeros((2,3))
for i in range(0, 2):
    for j in range(0, 3):
        median_ages[i,j] = df[(df['Gender'] == i) & \
                              (df['Pclass'] == j+1)]['Age'].dropna().median()
 
median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
df['AgeFill'] = df['Age']
for i in range(0, 2):
    for j in range(0, 3):
        df.loc[ (df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1),\
                'AgeFill'] = median_ages[i,j]
df['AgeIsNull'] = pd.isnull(df.Age).astype(int)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      Gender       Start     AgeFill   AgeIsNull
# count  891.000000  891.000000  891.000000  889.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.647587    0.897638   29.112424    0.198653
# std      0.806057   49.693429    0.477990    0.515181   13.304424    0.399210
# min      0.000000    0.000000    0.000000    0.000000    0.420000    0.000000
# 25%      0.000000    7.910400    0.000000    1.000000   21.500000    0.000000
# 50%      0.000000   14.454200    1.000000    1.000000   26.000000    0.000000
# 75%      0.000000   31.000000    1.000000    1.000000   36.000000    0.000000
# max      6.000000  512.329200    1.000000    2.000000   80.000000    1.000000
