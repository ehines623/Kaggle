# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
train_set = pd.read_csv('/home/ehines/Kaggle/GGG/train.csv')
train_set.head()
# Out:
#    id  bone_length  rotting_flesh  hair_length  has_soul  color    type
# 0   0     0.354512       0.350839     0.465761  0.781142  clear   Ghoul
# 1   1     0.575560       0.425868     0.531401  0.439899  green  Goblin
# 2   2     0.467875       0.354330     0.811616  0.791225  black   Ghoul
# 3   4     0.776652       0.508723     0.636766  0.884464  black   Ghoul
# 4   5     0.566117       0.875862     0.418594  0.636438  green   Ghost

# %%
train_set.describe()
# Out:
#                id  bone_length  rotting_flesh  hair_length    has_soul
# count  371.000000   371.000000     371.000000   371.000000  371.000000
# mean   443.676550     0.434160       0.506848     0.529114    0.471392
# std    263.222489     0.132833       0.146358     0.169902    0.176129
# min      0.000000     0.061032       0.095687     0.134600    0.009402
# 25%    205.500000     0.340006       0.414812     0.407428    0.348002
# 50%    458.000000     0.434891       0.501552     0.538642    0.466372
# 75%    678.500000     0.517223       0.603977     0.647244    0.600610
# max    897.000000     0.817001       0.932466     1.000000    0.935721

# %% [markdown]
# # Some Exploratory Plots

# %%
train_set.groupby('type').describe()
# Out:
#               bone_length  hair_length    has_soul          id  rotting_flesh
# type
# Ghost  count   117.000000   117.000000  117.000000  117.000000     117.000000
#        mean      0.347466     0.373186    0.320023  436.538462       0.593759
#        std       0.117748     0.117642    0.139790  250.974945       0.142150
#        min       0.061032     0.134600    0.009402    5.000000       0.165539
#        25%       0.269748     0.299507    0.230361  222.000000       0.504399
#        50%       0.340442     0.365142    0.307534  428.000000       0.603780
#        75%       0.417253     0.461068    0.415930  641.000000       0.682687
#        max       0.622371     0.636340    0.689980  896.000000       0.932466
# Ghoul  count   129.000000   129.000000  129.000000  129.000000     129.000000
#        mean      0.517159     0.655550    0.601634  464.054264       0.490515
#        std       0.120600     0.138127    0.134813  276.506338       0.115357
# ...

# %%
ghosts = train_set[train_set['type']=='Ghost']
ghouls = train_set[train_set['type']=='Ghoul']
goblins = train_set[train_set['type']=='Goblin']

# %%
# Out:
#     id  bone_length  rotting_flesh  hair_length  has_soul  color   type
# 4    5     0.566117       0.875862     0.418594  0.636438  green  Ghost
# 8   12     0.314295       0.671280     0.417267  0.227548   blue  Ghost
# 9   19     0.280942       0.701457     0.179633  0.141183  white  Ghost
# 16  30     0.250770       0.246258     0.554654  0.250036  black  Ghost
# 19  34     0.524080       0.750988     0.524637  0.443358  green  Ghost
